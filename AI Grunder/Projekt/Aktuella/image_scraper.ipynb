# %%
import os
import time

import io
import hashlib
import signal
from glob import glob
import requests

from PIL import Image
from selenium import webdriver

# %%
number_of_images = 10
GET_IMAGE_TIMEOUT = 2
SLEEP_BETWEEN_INTERACTIONS = 0.1
SLEEP_BEFORE_MORE = 5
IMAGE_QUALITY = 85

output_path = "C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images"

# %%
search_terms = [
    "slaguggla",
    "ural owl"
]

# %%
dirs = glob(output_path + "*")
dirs = [dir.split("/")[-1].replace("_", " ") for dir in dirs]
search_terms = [term for term in search_terms if term not in dirs]

# %%
class timeout:
    def __init__(self, seconds=1, error_message="Timeout"):
        self.seconds = seconds
        self.error_message = error_message

    def handle_timeout(self, signum, frame):
        raise TimeoutError(self.error_message)

    def __enter__(self):
        pass
        #signal.signal(signal.SIGALRM, self.handle_timeout)
        #signal.alarm(self.seconds)

    def __exit__(self, type, value, traceback):
        pass
        #signal.alarm(0)

# %%
def fetch_image_urls(
    query: str,
    max_links_to_fetch: int,
    wd: webdriver,
    sleep_between_interactions: int = 1,
):
    def scroll_to_end(wd):
        wd.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(sleep_between_interactions)

    # Build the Google Query.
    search_url = "https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img"

    # load the page
    wd.get(search_url.format(q=query))

    # Declared as a set, to prevent duplicates.
    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)

        # Get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector("img.Q4LuWd")
        number_results = len(thumbnail_results)

        print(
            f"Found: {number_results} search results. Extracting links from {results_start}:{number_results}"
        )

        # Loop through image thumbnail identified
        for img in thumbnail_results[results_start:number_results]:
            # Try to click every thumbnail such that we can get the real image behind it.
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue

            # Extract image urls
            actual_images = wd.find_elements_by_css_selector("img.n3VNCb")
            for actual_image in actual_images:
                if actual_image.get_attribute(
                    "src"
                ) and "http" in actual_image.get_attribute("src"):
                    image_urls.add(actual_image.get_attribute("src"))

            image_count = len(image_urls)

            # If the number images found exceeds our `num_of_images`, end the seaerch.
            if len(image_urls) >= max_links_to_fetch:
                print(f"Found: {len(image_urls)} image links, done!")
                break
        else:
            # If we haven't found all the images we want, let's look for more.
            print("Found:", len(image_urls), "image links, looking for more ...")
            time.sleep(SLEEP_BEFORE_MORE)

            # Check for button signifying no more images.
            not_what_you_want_button = ""
            try:
                not_what_you_want_button = wd.find_element_by_css_selector(".r0zKGf")
            except:
                pass

            # If there are no more images return.
            if not_what_you_want_button:
                print("No more images available.")
                return image_urls

            # If there is a "Load More" button, click it.
            load_more_button = wd.find_element_by_css_selector(".mye4qd")
            if load_more_button and not not_what_you_want_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")

        # Move the result startpoint further down.
        results_start = len(thumbnail_results)

    return image_urls


def persist_image(folder_path: str, url: str):
    try:
        print("Getting image")
        # Download the image.  If timeout is exceeded, throw an error.
        with timeout(GET_IMAGE_TIMEOUT):
            image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - Could not download {url} - {e}")

    try:
        # Convert the image into a bit stream, then save it.
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert("RGB")
        # Create a unique filepath from the contents of the image.
        file_path = os.path.join(
            folder_path, hashlib.sha1(image_content).hexdigest()[:10] + ".jpg"
        )
        with open(file_path, "wb") as f:
            image.save(f, "JPEG", quality=IMAGE_QUALITY)
        print(f"SUCCESS - saved {url} - as {file_path}")
    except Exception as e:
        print(f"ERROR - Could not save {url} - {e}")

def search_and_download(search_term: str, target_path="C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images", number_images=5):
    # Create a folder name.
    target_folder = os.path.join(target_path, "_".join(search_term.lower().split(" ")))

    # Create image folder if needed.
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # Open Chrome
    with webdriver.Chrome() as wd:
        # Search for images URLs.
        res = fetch_image_urls(
            search_term,
            number_images,
            wd=wd,
            sleep_between_interactions=SLEEP_BETWEEN_INTERACTIONS,
        )

        # Download the images.
        if res is not None:
            for elem in res:
                persist_image(target_folder, elem)
        else:
            print(f"Failed to return links for term: {search_term}")

# Loop through all the search terms.
for term in search_terms:
    search_and_download(term, output_path, number_of_images)
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 11 image links, done!
# Getting image
# SUCCESS - saved https://www.luontoportti.com/suomi/images/15542.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\03b64840d8.jpg
# Getting image
# SUCCESS - saved https://vof.birdlife.se/wp-content/uploads/sites/22/2018/08/slaguggla.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\0ca6986416.jpg
# Getting image
# SUCCESS - saved https://www.vaasa.fi/uploads/2019/12/046bd245-luontosivut.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\ab3be46c1a.jpg
# Getting image
# SUCCESS - saved https://naturforskaren.se/media/get-stream/b79b3eaf-cd47-4fa9-9c4c-a51a143fedf4 - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\a643c6024a.jpg
# Getting image
# SUCCESS - saved https://static-cdn.sr.se/images/1027/a02208d6-4689-4e57-b22e-df3b604f0ee3.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\36ed66b11e.jpg
# Getting image
# SUCCESS - saved https://i.pinimg.com/originals/7e/06/af/7e06af938f14e8da9851682dc484cd4e.png - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\584904511f.jpg
# Getting image
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnyNRW9zqjEB2reoV8Q_dPPskMKRtsHW0HHA&usqp=CAU - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\2897a3e0a4.jpg
# Getting image
# SUCCESS - saved http://www.natursidan.se/wp-content/uploads/2016/03/slaguggla-kattuggla.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\1d2a2c9e1c.jpg
# Getting image
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSoSEJA2h_TZTwYaJqAVr_jQ_uvCYMnEmPAAw&usqp=CAU - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\340f836c57.jpg
# Getting image
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRijRkPR4CZ3v38yRkOnG2KDs-Htn56Vrz0GA&usqp=CAU - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\d029dea640.jpg
# Getting image
# SUCCESS - saved https://i.ytimg.com/vi/ttAvvizOhfU/maxresdefault.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\slaguggla\a04221d42d.jpg
# Found: 100 search results. Extracting links from 0:100
# Found: 10 image links, done!
# Getting image
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Strix_uralensis.jpg/220px-Strix_uralensis.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\10d0284c7d.jpg
# Getting image
# SUCCESS - saved https://upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Strix_uralensis_0a1.JPG/220px-Strix_uralensis_0a1.JPG - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\a5577af591.jpg
# Getting image
# SUCCESS - saved https://cdn.download.ams.birds.cornell.edu/api/v1/asset/55028191/320 - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\345feeb082.jpg
# Getting image
# SUCCESS - saved https://cdn.download.ams.birds.cornell.edu/api/v1/asset/106598521/ - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\650eb2d8ba.jpg
# Getting image
# SUCCESS - saved http://www.10000birds.com/wp-content/uploads/panjkovici.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\04ee5a3d30.jpg
# Getting image
# SUCCESS - saved https://i.natgeofe.com/n/903c9081-f3ca-4d51-a834-89f34fd8f6a6/01-ural-owl.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\94b369df4a.jpg
# Getting image
# SUCCESS - saved https://www.larsfoto.se/img/images/large/2794_ural-owl_slaguggla_strix-uralensis-liturata_vastmanland_20110522_2_1000n.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\f30de52ecf.jpg
# Getting image
# SUCCESS - saved https://cdn.pixabay.com/photo/2020/04/16/21/00/ural-owl-5052346_960_720.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\cfc04ec819.jpg
# Getting image
# SUCCESS - saved https://live.staticflickr.com/7047/6830941118_e982723c88_c.jpg - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\2ed83d20a4.jpg
# Getting image
# SUCCESS - saved https://www.paigntonzoo.org.uk/userfiles/animals/images/ural-owl.jpg?w=500&h=600&zc=1&hash=467e7c28ef691b273a01eec14fc06b8c - as C:/Development/AI/ai-dataanalys-BBA-ta-suniL/AI Grunder/Projekt/images\ural_owl\2f17efb2f3.jpg
